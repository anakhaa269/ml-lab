# %% [markdown]
# <a href="https://colab.research.google.com/github/anakhaa269/ml-lab/blob/main/house%20sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Reading the data file
df = pd.read_csv("/content/housing.csv")
#print the datframe
print(df)
#printing the shape
print(df.shape)
#printing top 10 and bottom 10 rows
print(df.head(10))
print(df.tail(10))
#printing the columns
print(df.columns)
#print a feature value
print(df['Avg. Area Number of Rooms'])
# Selecting one input feature and target feature (dependent) for 150 rows only
X = df['Avg. Area Number of Rooms'].head(150).values.reshape(-1,1)
y = df['Price'].head(150).values.reshape(-1, 1)

#visualizing these values
plt.scatter(X, y)
plt.xlabel("Avg. Area Number of Rooms")
plt.ylabel("Price")
plt.title("Scatter Plot of Avg. Area Number of Rooms vs. Price")
plt.show()

#printing the statistical summary
print(df.describe())
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...
